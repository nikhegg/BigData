# %%
import pandas as pd
from collections import Counter

def map_chunk(df_chunk):
    counter = Counter()

    df_filtered = df_chunk[df_chunk["votes_helpful"] >= 3]

    for _, row in df_filtered.iterrows():
        key = (row["app_id"], row["app_name"])
        counter[key] += 1

    return counter

def shuffle(mapped_counters):
    total = Counter()
    for counter in mapped_counters:
        total.update(counter)
    return total

def reduce(shuffeled_counter):
    return shuffeled_counter.most_common()

def map_reduce(file, chunk_size=200_000):
    print(file)

    mapped = []
    handled_reviews = set()

    chunks = pd.read_csv(
        file,
        usecols = ["app_id", "app_name", "review_id", "votes_helpful"],
        dtype = {
            "app_id": "string",
            "app_name": "string",
            "review_id": "string",
            "votes_helpful": "Int64"
        },
        chunksize = chunk_size,
        # low_memory = True,
        engine = "c"
    )

    for chunk in chunks:
        chunk = chunk.dropna(subset=["review_id"])
        
        mask_new = ~chunk["review_id"].isin(handled_reviews)
        chunk_new = chunk.loc[mask_new]

        chunk_new = chunk_new.drop_duplicates(subset=["review_id"])

        if not chunk_new.empty:
            mapped.append(map_chunk(chunk_new))
            handled_reviews.update(chunk_new["review_id"].unique())

    shuffled = shuffle(mapped)
    result = reduce(shuffled)

    return result


file = r"./data/steam_reviews.csv"
result = map_reduce(file)

print("Статистика полезных отзывов у игр")
for (app_id, app_name), helpful_count in result:
    print(f"{app_name} ({app_id}) - {helpful_count}")
# Out:
# ./data/steam_reviews.csv
# Статистика полезных отзывов у игр
# PLAYERUNKNOWN'S BATTLEGROUNDS (578080) - 75241
# Grand Theft Auto V (271590) - 55543
# No Man's Sky (275850) - 42819
# PAYDAY 2 (218620) - 39084
# Fallout 4 (377160) - 37719
# ARK: Survival Evolved (346110) - 37594
# Tom Clancy's Rainbow Six Siege (359550) - 35486
# Rust (252490) - 28336
# Dead by Daylight (381210) - 27428
# The Witcher 3: Wild Hunt (292030) - 25383
# Garry's Mod (4000) - 23572
# Rocket League (252950) - 20632
# Terraria (105600) - 20367
# The Elder Scrolls V: Skyrim (72850) - 17589
# DARK SOULS™ III (374320) - 15544
# Euro Truck Simulator 2 (227300) - 14938
# The Forest (242760) - 14567
# NieR:Automata™ (524220) - 13947
# Sid Meier's Civilization VI (289070) - 13728
# The Elder Scrolls Online (306130) - 13465
# Arma 3 (107410) - 13272
# Monster Hunter: World (582010) - 13224
# Stardew Valley (413150) - 13158
# The Elder Scrolls V: Skyrim Special Edition (489830) - 13069
# For Honor (304390) - 12632
# Dying Light (239140) - 12379
# Stellaris (281990) - 12339
# Darkest Dungeon® (262060) - 12318
# Undertale (391540) - 12285
# Hunt: Showdown (594650) - 11319
# Total War: WARHAMMER (364360) - 11153
# DOOM (379720) - 10606
# Don't Starve Together (322330) - 10194
# Subnautica (264710) - 10179
# Conan Exiles (440900) - 10067
# Europa Universalis IV (236850) - 9894
# Kingdom Come: Deliverance (379430) - 9779
# Warhammer 40,000: Dawn of War III (285190) - 9433
# Doki Doki Literature Club (698780) - 9200
# Cities: Skylines (255710) - 8937
# Tomb Raider (203160) - 8481
# BioShock Infinite (8870) - 8403
# Mount & Blade: Warband (48700) - 8366
# Artifact (583950) - 8280
# Sid Meier's Civilization V (8930) - 8186
# Portal 2 (620) - 8164
# Wallpaper Engine (431960) - 8082
# DOOM Eternal (782330) - 8063
# Divinity: Original Sin 2 (435150) - 8005
# ATLAS (834910) - 7960
# Hearts of Iron IV (394360) - 7602
# Counter-Strike: Source (240) - 7573
# Far Cry 5 (552520) - 7531
# Rise of the Tomb Raider (391220) - 6941
# Assassin's Creed Origins (582160) - 6890
# Total War: ROME II - Emperor Edition (214950) - 6665
# Factorio (427520) - 6654
# Just Cause 3 (225540) - 6588
# Sekiro™: Shadows Die Twice (814380) - 6583
# XCOM 2 (268500) - 6559
# Tom Clancy's Ghost Recon® Wildlands (460930) - 6514
# Warhammer: Vermintide 2 (552500) - 6491
# RimWorld (294100) - 6424
# Call of Duty: WWII (476600) - 6409
# SCUM (513710) - 6330
# theHunter: Call of the Wild™ (518790) - 6232
# Middle-earth™: Shadow of War™ (356190) - 6208
# Hollow Knight (367520) - 6183
# Assassin's Creed Odyssey (812140) - 6175
# The Binding of Isaac: Rebirth (250900) - 6086
# Outlast (238320) - 6002
# Total War: WARHAMMER II (594570) - 5977
# Watch_Dogs 2 (447040) - 5898
# MORDHAU (629760) - 5803
# To the Moon (206440) - 5678
# Among Us (945360) - 5644
# DARK SOULS™: REMASTERED (570940) - 5478
# Resident Evil 2 (883710) - 5256
# Total War: THREE KINGDOMS (779340) - 5230
# Call of Duty: Infinite Warfare (292730) - 5227
# Black Mesa (362890) - 5119
# Frostpunk (323190) - 5082
# Age of Empires II (2013) (221380) - 5078
# The Walking Dead (207610) - 5057
# Resident Evil 7 Biohazard (418370) - 5056
# Insurgency: Sandstorm (581320) - 5019
# Cube World (1128000) - 5004
# Cuphead (268910) - 4989
# American Truck Simulator (270880) - 4972
# Planet Coaster (493340) - 4968
# Mirror (644560) - 4893
# Black Desert Online (582660) - 4769
# Jurassic World Evolution (648350) - 4577
# Hotline Miami (219150) - 4418
# Half-Life (70) - 4397
# FINAL FANTASY XV WINDOWS EDITION (637650) - 4330
# Kenshi (233860) - 4310
# Raft (648800) - 4308
# Papers, Please (239030) - 4228
# Deep Rock Galactic (548430) - 4111
# Saints Row: The Third (55230) - 4105
# Slime Rancher (433340) - 4098
# Bless Online (681660) - 4087
# Pathfinder: Kingmaker (640820) - 4048
# Human: Fall Flat (477160) - 4018
# Getting Over It with Bennett Foddy (240720) - 3977
# DEATH STRANDING (1190460) - 3918
# Borderlands 3 (397540) - 3916
# Oxygen Not Included (457140) - 3912
# Castle Crashers (204360) - 3863
# Nioh: Complete Edition (485510) - 3843
# Enter the Gungeon (311690) - 3803
# FINAL FANTASY XIV Online (39210) - 3781
# Dishonored (205100) - 3749
# X Rebirth (2870) - 3680
# Tabletop Simulator (286160) - 3660
# Just Cause 4 (517630) - 3632
# The Crew 2 (646910) - 3604
# Half-Life: Alyx (546560) - 3593
# BattleBlock Theater (238460) - 3583
# They Are Billions (644930) - 3580
# Don't Starve (219740) - 3578
# Day of Infamy (447820) - 3564
# BATTLETECH (637090) - 3507
# The Sims(TM) 3 (47890) - 3466
# Phasmophobia (739630) - 3395
# DYNASTY WARRIORS 9 (730310) - 3376
# BeamNG.drive (284160) - 3373
# South Park™: The Stick of Truth™ (213670) - 3365
# Banished (242920) - 3343
# Dead Cells (588650) - 3333
# The Binding of Isaac (113200) - 3274
# Northgard (466560) - 3267
# FTL: Faster Than Light (212680) - 3253
# Yakuza 0 (638970) - 3245
# Broforce (274190) - 3243
# Persona 4 Golden (1113000) - 3219
# HITMAN™ 2 (863550) - 3207
# HuniePop (339800) - 3155
# Total War Saga: Thrones of Britannia (712100) - 3106
# BATTALION 1944 (489940) - 3090
# VA-11 Hall-A: Cyberpunk Bartender Action (447530) - 3046
# Nether (247730) - 3014
# Wolfenstein: Youngblood (1056960) - 2993
# Sniper Elite 4 (312660) - 2992
# Blackwake (420290) - 2979
# NBA 2K18 (577800) - 2961
# DRAGON BALL FighterZ (678950) - 2855
# Vampyr (427290) - 2844
# PC Building Simulator (621060) - 2840
# The Wolf Among Us (250320) - 2837
# Hades (1145360) - 2723
# A Hat in Time (253230) - 2722
# My Time At Portia (666140) - 2660
# Slay the Spire (646570) - 2611
# Totally Accurate Battlegrounds (823130) - 2608
# Beat Saber (620980) - 2593
# METAL GEAR SURVIVE (543900) - 2569
# GRIS (683320) - 2516
# Batman: Arkham Asylum GOTY Edition (35140) - 2476
# RollerCoaster Tycoon World (282560) - 2468
# DiRT 4 (421020) - 2453
# House Flipper (613100) - 2413
# Helltaker (1289310) - 2404
# Half-Life 2: Episode Two (420) - 2389
# Ravenfield (636480) - 2349
# NBA 2K19 (841370) - 2263
# Farming Simulator 19 (787860) - 2260
# Sword Art Online: Fatal Bullet (626690) - 2239
# Duck Game (312530) - 2226
# Super Meat Boy (40800) - 2196
# Steel Division: Normandy 44 (572410) - 2176
# Torment: Tides of Numenera (272270) - 2144
# Little Nightmares (424840) - 2141
# Freeman: Guerrilla Warfare (773951) - 2117
# Youtubers Life (428690) - 2091
# OneShot (420530) - 2084
# Two Point Hospital (535930) - 2077
# Crusader Kings III (1158310) - 2073
# Celeste (504230) - 2064
# STEINS;GATE (412830) - 2063
# Surviving Mars (464920) - 2024
# Super Hexagon (221640) - 2021
# Tales of Berseria (429660) - 2021
# Darksiders III (606280) - 2013
# Salt and Sanctuary (283640) - 1966
# Night in the Woods (481510) - 1945
# Pillars of Eternity II: Deadfire (560130) - 1908
# Danganronpa: Trigger Happy Havoc (413410) - 1828
# SOS (619080) - 1719
# Ori and the Will of the Wisps (1057090) - 1718
# Detention (555220) - 1695
# Danganronpa 2: Goodbye Despair (413420) - 1680
# Satisfactory (526870) - 1679
# SOULCALIBUR VI (544750) - 1670
# Totally Accurate Battle Simulator (508440) - 1669
# PixARK (593600) - 1644
# For The King (527230) - 1641
# Takedown: Red Sabre (236510) - 1640
# NBA 2K21 (1225330) - 1605
# Overcooked! 2 (728880) - 1601
# Desolate (671510) - 1572
# Train Sim World® 2020 (530070) - 1544
# STAR WARS™ Empire at War: Gold Pack (32470) - 1455
# Crash Bandicoot™ N. Sane Trilogy (731490) - 1431
# The Wild Eight (526160) - 1426
# Farm Together (673950) - 1377
# Ni no Kuni™ II: Revenant Kingdom (589360) - 1376
# Urban Empire (352550) - 1363
# X-Plane 11 (269950) - 1362
# Shovel Knight: Treasure Trove (250760) - 1342
# Football Manager 2019 (872790) - 1326
# Keep Talking and Nobody Explodes (341800) - 1308
# Bloons TD 6 (960090) - 1292
# Dead Rising 4 (543460) - 1283
# Phoenix Wright: Ace Attorney Trilogy (787480) - 1272
# Finding Paradise (337340) - 1266
# Titan Souls (297130) - 1265
# Hunt Down The Freeman (723390) - 1232
# Avorion (445220) - 1227
# Streets of Rogue (512900) - 1226
# DUSK (519860) - 1223
# One Finger Death Punch (264200) - 1219
# Mark of the Ninja (214560) - 1217
# Thief Simulator (704850) - 1186
# Eco (382310) - 1179
# Umbrella Corps (390340) - 1173
# SENRAN KAGURA ESTIVAL VERSUS (502800) - 1123
# Into the Breach (590380) - 1100
# CHRONO TRIGGER (613830) - 1099
# Ancestors Legacy (620590) - 1086
# Stay Out (1180380) - 1069
# The Room (288160) - 1059
# Mutant Year Zero: Road to Eden (760060) - 1054
# Pit People (291860) - 1051
# Deus Ex: The Fall (258180) - 1045
# Baba Is You (736260) - 1037
# Momodora: Reverie Under the Moonlight (428550) - 1007
# Railway Empire (503940) - 1004
# Bomber Crew (537800) - 1003
# Identity (792990) - 969
# Golf It! (571740) - 966
# Monster Prom (743450) - 948
# FINAL FANTASY XII THE ZODIAC AGE (595520) - 948
# Rules Of Survival (788260) - 943
# GOD EATER 3 (899440) - 930
# Devil May Cry HD Collection (631510) - 925
# Foundation (690830) - 914
# The Henry Stickmin Collection (1089980) - 901
# SENRAN KAGURA Peach Beach Splash (696170) - 894
# Cold Waters (541210) - 867
# FAR: Lone Sails (609320) - 862
# Ghost of a Tale (417290) - 846
# Gunpoint (206190) - 821
# Cyberdimension Neptunia: 4 Goddesses Online (632350) - 797
# STEINS;GATE 0 (825630) - 781
# Kingdom Two Crowns (701160) - 781
# Age of Empires: Definitive Edition (1017900) - 780
# Puyo Puyo™Tetris®  (546050) - 777
# Cave Story+ (200900) - 775
# Rise of Industry (671440) - 774
# People Playground (1118200) - 745
# Just Shapes & Beats (531510) - 738
# Clicker Heroes 2 (629910) - 736
# Warhammer 40,000: Mechanicus (673880) - 730
# Staxel (405710) - 727
# Styx: Shards of Darkness (355790) - 712
# Ultimate Marvel vs. Capcom 3 (357190) - 703
# BERSERK and the Band of the Hawk (502280) - 702
# A Way Out (1222700) - 688
# The Room Two (425580) - 686
# Secret of Mana (637670) - 675
# WWE 2K20 (1015500) - 670
# We Were Here Too (677160) - 587
# Dragon Cliff 龙崖 (758190) - 580
# Heroes of Hammerwatch (677120) - 569
# Axiom Verge (332200) - 565
# 20XX (322110) - 561
# Townscaper (1291340) - 547
# Thimbleweed Park (569860) - 535
# WWE 2K19 (817130) - 527
# X-Blades (7510) - 526
# Trailmakers (585420) - 523
# SimAirport (598330) - 515
# Toukiden 2 (551730) - 513
# Senren＊Banka (1144400) - 510
# Void Bastards (857980) - 505
# Down To One (334040) - 498
# A Short Hike (1055540) - 487
# Iconoclasts (393520) - 485
# Fairy Fencer F Advent Dark Force (524580) - 480
# Dungreed (753420) - 474
# Volgarr the Viking (247240) - 473
# Guacamelee! Super Turbo Championship Edition (275390) - 449
# WWE 2K17 (510510) - 448
# The End Is Nigh (583470) - 416
# Farm Manager 2018 (495560) - 410
# ULTRAKILL (1229490) - 393
# Battle Royale Trainer (772540) - 389
# 三国群英传8 Heroes of the Three Kingdoms 8 (875210) - 386
# Rapture Rejects (686600) - 379
# Fishing: Barents Sea (501080) - 359
# There Is No Game: Wrong Dimension (1240210) - 354
# Due Process (753650) - 333
# The Legend of Heroes: Trails of Cold Steel II (748490) - 331
# Grimm's Hollow (1170880) - 320
# Pogostuck: Rage With Your Friends (688130) - 299
# Budget Cuts (400940) - 252
# DRAGON QUEST HEROES™ II (574050) - 237
# Slipstream (732810) - 211
# Nova Drift (858210) - 204
# Shadow Complex Remastered (385560) - 161
# Don't Escape: 4 Days to Survive (611760) - 144
# Out of the Park Baseball 19 (619290) - 89
# Neon Hardcorps (454200) - 18
